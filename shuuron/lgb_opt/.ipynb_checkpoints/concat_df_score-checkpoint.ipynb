# %%
pwd
# Out:
# '/home/chin/rnaphasep_vs/clf_mor/vs_1226/lgb_opt'

# %%
import numpy as np
import pandas as pd
import yaml
import glob

import sklearn.metrics as metrics
import matplotlib.pyplot as plt

with open("./config_.yaml",'r')as f:
    args = yaml.safe_load(f)

target_label = args["target_label"]
group_label = args["group_label"]
ignore_features = args["ignore_features"]
fold_strategy = args["fold_strategy"]
val_fold_strategy = args["val_fold_strategy"]
n_splits = args["n_splits"]
random_state = args["random_state"]

mor_class = np.array(args["mor_class"])
data_dict = {}
X_dict = {}
y_dict = {}
group_dict = {}

max_num = args["max_num"]
min_num = args["min_num"]
early_stopping_num = args["early_stopping"]
val_fold = args["val_fold"]
data_dir = args["data_dir"]
file_name = "chin_isin_prepro"

fig = plt.figure(figsize=(10, 10))

# %%
file_list = []
path_list = []
max_num_list = [50, 80, 1108]
fold_strategy_list = ["LeaveOneGroupOut", "GroupKFold", "StratifiedKFold",]
for max_num in max_num_list:
    for fold_strategy in fold_strategy_list:
        for val_fold_strategy in fold_strategy_list:
#             print(max_num, fold_strategy, val_fold_strategy)
            path = glob.glob(f"./result_cutdata_{file_name}/data_{min_num}_{max_num}/opt/cv_{fold_strategy}_valsplit_{val_fold_strategy}/es_{early_stopping_num}_val_fold_{val_fold}/score.csv")
            if len(path) > 0:
                
                print(pd.read_csv(path[0]))
                file_list.append(pd.read_csv(path[0]).rename(index =
                                                             {0:f"{file_name}/data_{min_num}_{max_num}/opt/cv_{fold_strategy}_valsplit_{val_fold_strategy}"}))
pd.concat(file_list, axis = "index").to_csv(f"./{file_name}_{fold_strategy}_{val_fold}_opt_score_concat.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d59935e9c1eb> in <module>
#      13                 file_list.append(pd.read_csv(path[0]).rename(index =
#      14                                                              {0:f"{file_name}/data_{min_num}_{max_num}/cv_{fold_strategy}_valsplit_{val_fold_strategy}"}))
# ---> 15 pd.concat(file_list, axis = "index").to_csv(f"./{file_name}_score_concat.csv")
#
# ~/.pyenv/versions/miniconda3-4.2.12/envs/calc2/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# ~/.pyenv/versions/miniconda3-4.2.12/envs/calc2/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     329
#     330         if len(objs) == 0:
# --> 331             raise ValueError("No objects to concatenate")
#     332
#     333         if keys is None:
#
# ValueError: No objects to concatenate

# %%
df_chin_isin = pd.concat(file_list, axis = "index")

# %%
path_list
# Out:
# []

# %%
file_name_list = ["prepro", "chin", "chin_isin_prepro"]
score_list = []
for file_name in file_name_list:
    file_list = []
    path_list = []
    max_num_list = [50, 80, 223, 1381, 1108]
    fold_strategy_list = ["LeaveOneGroupOut", "GroupKFold", "StratifiedKFold",]
    for max_num in max_num_list:
        for fold_strategy in fold_strategy_list:
            for val_fold_strategy in fold_strategy_list:
    #             print(max_num, fold_strategy, val_fold_strategy)
                path = glob.glob(f"./result_cutdata_{file_name}/data_{min_num}_{max_num}/cv_{fold_strategy}_valsplit_{val_fold_strategy}/es_{early_stopping_num}_val_fold_{val_fold}/score.csv")
                if len(path) > 0:

                    print(pd.read_csv(path[0]))
                    file_list.append(pd.read_csv(path[0]).rename(index =
                                                                 {0:f"{file_name}/data_{min_num}_{max_num}/cv_{fold_strategy}_valsplit_{val_fold_strategy}"}))
    pd.concat(file_list, axis = "index").to_csv(f"./{file_name}_score_concat.csv")
    score_list.append(pd.concat(file_list, axis = "index"))
# Out:
#     roc_auc    pr_auc  accuracy  specificity  precision  recall  f1_score  \
# 0  0.555091  0.869098  0.843049          0.0   0.843049     1.0  0.914842
#
#    macro_precision  macro_recall  macro_f1  kappa  mcc  hinge_loss  neg_f1  \
# 0         0.421525           0.5  0.457421    0.0  0.0    0.404221     0.0
#
#     neg_roc
# 0  0.444909
#    roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.65266  0.896701  0.834081     0.028571   0.844749  0.984043  0.909091
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.547374      0.506307  0.480186  0.019722  0.034571    0.387846
#
#      neg_f1  neg_roc
# 0  0.051282  0.34734
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.659802  0.888512  0.852018     0.085714   0.853881  0.994681  0.918919
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.801941      0.540198  0.536383  0.125698  0.220339    0.375151
#
#      neg_f1   neg_roc
# 0  0.153846  0.340198
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.834574  0.951989  0.843049     0.314286   0.880597  0.941489  0.910026
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.690299      0.627888  0.647995  0.301316  0.312005    0.308659
#
#      neg_f1   neg_roc
# 0  0.385965  0.165426
#    roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.53366  0.740966  0.659472     0.007968   0.687578  0.939966  0.794203
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.370816      0.473967  0.404046 -0.068758 -0.115984     0.72156
#
#      neg_f1  neg_roc
# 0  0.013889  0.46634
#    roc_auc   pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.48869  0.72063  0.618705     0.195219   0.698057  0.801029  0.746006
#
#    macro_precision  macro_recall  macro_f1     kappa      mcc  hinge_loss  \
# 0         0.497513      0.498124  0.490792 -0.004157 -0.00432     0.72261
#
#      neg_f1  neg_roc
# 0  0.235577  0.51131
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.448419  0.697867  0.565947     0.227092   0.681445  0.711835  0.696309
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.467389      0.469463  0.467902 -0.062929 -0.063113    0.751647
#
#      neg_f1   neg_roc
# 0  0.239496  0.551581
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.910844  0.953055  0.864508     0.729084   0.887789  0.922813  0.904962
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0          0.84521      0.825948  0.834527  0.669361  0.670882    0.488436
#
#      neg_f1   neg_roc
# 0  0.764092  0.089156
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.302625  0.609935   0.59415     0.012232   0.666667  0.842243   0.74424
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.349333      0.427237  0.380969 -0.176863 -0.209408    0.776331
#
#      neg_f1   neg_roc
# 0  0.017699  0.697375
#     roc_auc  pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.512454  0.7195  0.604205     0.171254   0.690639  0.788787  0.736458
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0          0.47376      0.480021  0.470981 -0.044183 -0.045793    0.715011
#
#      neg_f1   neg_roc
# 0  0.205505  0.487546
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.556152  0.737751  0.689214       0.2263   0.728832  0.886571       0.8
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0          0.59423      0.556435  0.551639  0.132107  0.145848    0.660458
#
#      neg_f1   neg_roc
# 0  0.303279  0.443848
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.939077  0.971859   0.88574     0.785933   0.910486  0.928292  0.919303
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.867102      0.857112  0.861842  0.723747  0.724145    0.459928
#
#      neg_f1   neg_roc
# 0  0.804382  0.060923
#    roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0   0.3994  0.656843  0.708182          0.0   0.716484  0.983903  0.829165
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.358242      0.491952  0.414582 -0.022758 -0.067555     0.70217
#
#    neg_f1  neg_roc
# 0     0.0   0.6006
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.434688  0.681056  0.596669     0.126615   0.696316  0.779678  0.735643
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.439576      0.453147  0.442631 -0.103416 -0.106416    0.704993
#
#      neg_f1   neg_roc
# 0  0.149618  0.565312
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.463837  0.711475  0.603186     0.136951    0.70018  0.784708  0.740038
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.449341       0.46083  0.451059 -0.086534 -0.089092    0.697747
#
#     neg_f1   neg_roc
# 0  0.16208  0.536163
#    roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.95579  0.979988  0.908038     0.806202   0.926254  0.947686  0.936847
#
#    macro_precision  macro_recall  macro_f1     kappa     mcc  hinge_loss  \
# 0         0.891698      0.876944   0.88387  0.767821  0.7685    0.396376
#
#      neg_f1  neg_roc
# 0  0.830892  0.04421
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.469381  0.638059  0.639205     0.025641   0.660714  0.944681  0.777583
#
#    macro_precision  macro_recall  macro_f1    kappa       mcc  hinge_loss  \
# 0         0.424107      0.485161  0.411348 -0.03789 -0.067117    0.783266
#
#      neg_f1   neg_roc
# 0  0.045113  0.530619
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.475686  0.638875  0.607955     0.183761   0.668403  0.819149  0.736138
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0          0.50217      0.501455  0.486853  0.003283  0.003554     0.74309
#
#      neg_f1   neg_roc
# 0  0.237569  0.524314
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.485902  0.681759  0.600852     0.196581   0.667257  0.802128  0.728502
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.499096      0.499354  0.487576 -0.001438 -0.001528    0.766216
#
#      neg_f1   neg_roc
# 0  0.246649  0.514098
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.913443  0.953237  0.849432     0.735043   0.872951  0.906383  0.889353
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.834624      0.820713  0.826899  0.654057  0.655189    0.542024
#
#      neg_f1   neg_roc
# 0  0.764444  0.086557
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.436479  0.617259  0.625414     0.032573   0.651817  0.929766  0.766368
#
#    macro_precision  macro_recall  macro_f1   kappa       mcc  hinge_loss  \
# 0         0.422062       0.48117  0.411039 -0.0472 -0.076618    0.793899
#
#     neg_f1   neg_roc
# 0  0.05571  0.563521
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.506743  0.661253  0.647514     0.263844   0.690834  0.844482   0.75997
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.578176      0.554163  0.548384  0.121089  0.130142    0.747256
#
#      neg_f1   neg_roc
# 0  0.336798  0.493257
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.537917  0.710717  0.644199      0.14658     0.6725  0.899666  0.769671
#
#    macro_precision  macro_recall  macro_f1    kappa       mcc  hinge_loss  \
# 0         0.550536      0.523123  0.494059  0.05506  0.068367    0.745805
#
#      neg_f1   neg_roc
# 0  0.218447  0.462083
#    roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.92116  0.954486  0.861878     0.771987   0.885808  0.908027   0.89678
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.848726      0.840007  0.844049  0.688195  0.688677    0.529981
#
#      neg_f1  neg_roc
# 0  0.791319  0.07884
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.480222  0.684684  0.634477     0.146893   0.683106  0.863395  0.762742
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.509295      0.505144  0.483532  0.012091  0.013829    0.782784
#
#      neg_f1   neg_roc
# 0  0.204322  0.519778
#     roc_auc   pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.513276  0.73023  0.557762     0.172316   0.655294  0.738727  0.694514
#
#    macro_precision  macro_recall  macro_f1     kappa      mcc  hinge_loss  \
# 0         0.445864      0.455522   0.44693 -0.095852 -0.09814    0.756034
#
#      neg_f1   neg_roc
# 0  0.199346  0.486724
#     roc_auc   pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.506067  0.73189  0.543321     0.146893    0.64554  0.729443  0.684932
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.424332      0.438168  0.427712 -0.133465 -0.136802    0.768264
#
#      neg_f1   neg_roc
# 0  0.170492  0.493933
#     roc_auc    pr_auc  accuracy  specificity  precision    recall  f1_score  \
# 0  0.944143  0.969444  0.886282     0.776836   0.899491  0.937666  0.918182
#
#    macro_precision  macro_recall  macro_f1     kappa       mcc  hinge_loss  \
# 0         0.876764      0.857251  0.865896  0.732055  0.733756    0.472223
#
#      neg_f1   neg_roc
# 0  0.813609  0.055857

# %%
df_score = pd.concat(score_list, axis = "index").reset_index().rename(columns = {"index": "idx"})

# %%
df_ds = df_score.idx.str.split("/", expand = True ).loc[:, [0, 1]]
df_cv = df_score.idx.str.split("/", expand = True ).loc[:, [2]]

# %%
df_cv = df_cv[2].str.split("_", expand = True).rename(columns = {1: "test", 3: "val"})
df_cv
# Out:
#      0              test         2              val
# 0   cv  LeaveOneGroupOut  valsplit       GroupKFold
# 1   cv  LeaveOneGroupOut  valsplit  StratifiedKFold
# 2   cv        GroupKFold  valsplit  StratifiedKFold
# 3   cv   StratifiedKFold  valsplit  StratifiedKFold
# 4   cv  LeaveOneGroupOut  valsplit       GroupKFold
# 5   cv  LeaveOneGroupOut  valsplit  StratifiedKFold
# 6   cv        GroupKFold  valsplit  StratifiedKFold
# 7   cv   StratifiedKFold  valsplit  StratifiedKFold
# 8   cv  LeaveOneGroupOut  valsplit       GroupKFold
# 9   cv  LeaveOneGroupOut  valsplit  StratifiedKFold
# 10  cv        GroupKFold  valsplit  StratifiedKFold
# 11  cv   StratifiedKFold  valsplit  StratifiedKFold
# 12  cv  LeaveOneGroupOut  valsplit       GroupKFold
# 13  cv  LeaveOneGroupOut  valsplit  StratifiedKFold
# 14  cv        GroupKFold  valsplit  StratifiedKFold
# 15  cv   StratifiedKFold  valsplit  StratifiedKFold
# 16  cv  LeaveOneGroupOut  valsplit       GroupKFold
# 17  cv  LeaveOneGroupOut  valsplit  StratifiedKFold
# 18  cv        GroupKFold  valsplit  StratifiedKFold
# 19  cv   StratifiedKFold  valsplit  StratifiedKFold
# 20  cv  LeaveOneGroupOut  valsplit       GroupKFold
# 21  cv  LeaveOneGroupOut  valsplit  StratifiedKFold
# 22  cv        GroupKFold  valsplit  StratifiedKFold
# 23  cv   StratifiedKFold  valsplit  StratifiedKFold
# 24  cv  LeaveOneGroupOut  valsplit       GroupKFold
# 25  cv  LeaveOneGroupOut  valsplit  StratifiedKFold
# 26  cv        GroupKFold  valsplit  StratifiedKFold
# 27  cv   StratifiedKFold  valsplit  StratifiedKFold

# %%
pwd
# Out:
# '/home/chin/rnaphasep_vs/clf_mor/vs_1226/main_cutdata'

# %%
pd.concat([df_ds, df_cv.loc[:, ["test", "val"]], df_score], axis = "columns").to_csv("./concat_result.csv")

# %%
pd.concat([df_ds, df_cv.loc[:, ["test", "val"]], df_score], axis = "columns").sort_values(by = ["test", "val"])
# Out:
#                    0            1              test              val  \
# 2             prepro   data_0_223        GroupKFold  StratifiedKFold
# 6               chin    data_0_50        GroupKFold  StratifiedKFold
# 10              chin    data_0_80        GroupKFold  StratifiedKFold
# 14              chin  data_0_1381        GroupKFold  StratifiedKFold
# 18  chin_isin_prepro    data_0_50        GroupKFold  StratifiedKFold
# 22  chin_isin_prepro    data_0_80        GroupKFold  StratifiedKFold
# 26  chin_isin_prepro  data_0_1108        GroupKFold  StratifiedKFold
# 0             prepro   data_0_223  LeaveOneGroupOut       GroupKFold
# 4               chin    data_0_50  LeaveOneGroupOut       GroupKFold
# 8               chin    data_0_80  LeaveOneGroupOut       GroupKFold
# 12              chin  data_0_1381  LeaveOneGroupOut       GroupKFold
# 16  chin_isin_prepro    data_0_50  LeaveOneGroupOut       GroupKFold
# 20  chin_isin_prepro    data_0_80  LeaveOneGroupOut       GroupKFold
# 24  chin_isin_prepro  data_0_1108  LeaveOneGroupOut       GroupKFold
# 1             prepro   data_0_223  LeaveOneGroupOut  StratifiedKFold
# 5               chin    data_0_50  LeaveOneGroupOut  StratifiedKFold
# 9               chin    data_0_80  LeaveOneGroupOut  StratifiedKFold
# 13              chin  data_0_1381  LeaveOneGroupOut  StratifiedKFold
# 17  chin_isin_prepro    data_0_50  LeaveOneGroupOut  StratifiedKFold
# 21  chin_isin_prepro    data_0_80  LeaveOneGroupOut  StratifiedKFold
# 25  chin_isin_prepro  data_0_1108  LeaveOneGroupOut  StratifiedKFold
# 3             prepro   data_0_223   StratifiedKFold  StratifiedKFold
# 7               chin    data_0_50   StratifiedKFold  StratifiedKFold
# 11              chin    data_0_80   StratifiedKFold  StratifiedKFold
# 15              chin  data_0_1381   StratifiedKFold  StratifiedKFold
# 19  chin_isin_prepro    data_0_50   StratifiedKFold  StratifiedKFold
# 23  chin_isin_prepro    data_0_80   StratifiedKFold  StratifiedKFold
# 27  chin_isin_prepro  data_0_1108   StratifiedKFold  StratifiedKFold
#
#                                                   idx   roc_auc    pr_auc  \
# 2   prepro/data_0_223/cv_GroupKFold_valsplit_Strat...  0.659802  0.888512
# 6   chin/data_0_50/cv_GroupKFold_valsplit_Stratifi...  0.448419  0.697867
# 10  chin/data_0_80/cv_GroupKFold_valsplit_Stratifi...  0.556152  0.737751
# 14  chin/data_0_1381/cv_GroupKFold_valsplit_Strati...  0.463837  0.711475
# 18  chin_isin_prepro/data_0_50/cv_GroupKFold_valsp...  0.485902  0.681759
# 22  chin_isin_prepro/data_0_80/cv_GroupKFold_valsp...  0.537917  0.710717
# 26  chin_isin_prepro/data_0_1108/cv_GroupKFold_val...  0.506067  0.731890
# 0   prepro/data_0_223/cv_LeaveOneGroupOut_valsplit...  0.555091  0.869098
# 4   chin/data_0_50/cv_LeaveOneGroupOut_valsplit_Gr...  0.533660  0.740966
# 8   chin/data_0_80/cv_LeaveOneGroupOut_valsplit_Gr...  0.302625  0.609935
# 12  chin/data_0_1381/cv_LeaveOneGroupOut_valsplit_...  0.399400  0.656843
# 16  chin_isin_prepro/data_0_50/cv_LeaveOneGroupOut...  0.469381  0.638059
# 20  chin_isin_prepro/data_0_80/cv_LeaveOneGroupOut...  0.436479  0.617259
# 24  chin_isin_prepro/data_0_1108/cv_LeaveOneGroupO...  0.480222  0.684684
# 1   prepro/data_0_223/cv_LeaveOneGroupOut_valsplit...  0.652660  0.896701
# 5   chin/data_0_50/cv_LeaveOneGroupOut_valsplit_St...  0.488690  0.720630
# 9   chin/data_0_80/cv_LeaveOneGroupOut_valsplit_St...  0.512454  0.719500
# 13  chin/data_0_1381/cv_LeaveOneGroupOut_valsplit_...  0.434688  0.681056
# 17  chin_isin_prepro/data_0_50/cv_LeaveOneGroupOut...  0.475686  0.638875
# 21  chin_isin_prepro/data_0_80/cv_LeaveOneGroupOut...  0.506743  0.661253
# 25  chin_isin_prepro/data_0_1108/cv_LeaveOneGroupO...  0.513276  0.730230
# 3   prepro/data_0_223/cv_StratifiedKFold_valsplit_...  0.834574  0.951989
# 7   chin/data_0_50/cv_StratifiedKFold_valsplit_Str...  0.910844  0.953055
# 11  chin/data_0_80/cv_StratifiedKFold_valsplit_Str...  0.939077  0.971859
# 15  chin/data_0_1381/cv_StratifiedKFold_valsplit_S...  0.955790  0.979988
# 19  chin_isin_prepro/data_0_50/cv_StratifiedKFold_...  0.913443  0.953237
# 23  chin_isin_prepro/data_0_80/cv_StratifiedKFold_...  0.921160  0.954486
# 27  chin_isin_prepro/data_0_1108/cv_StratifiedKFol...  0.944143  0.969444
#
#     accuracy  specificity  precision    recall  f1_score  macro_precision  \
# 2   0.852018     0.085714   0.853881  0.994681  0.918919         0.801941
# 6   0.565947     0.227092   0.681445  0.711835  0.696309         0.467389
# 10  0.689214     0.226300   0.728832  0.886571  0.800000         0.594230
# 14  0.603186     0.136951   0.700180  0.784708  0.740038         0.449341
# 18  0.600852     0.196581   0.667257  0.802128  0.728502         0.499096
# 22  0.644199     0.146580   0.672500  0.899666  0.769671         0.550536
# 26  0.543321     0.146893   0.645540  0.729443  0.684932         0.424332
# 0   0.843049     0.000000   0.843049  1.000000  0.914842         0.421525
# 4   0.659472     0.007968   0.687578  0.939966  0.794203         0.370816
# 8   0.594150     0.012232   0.666667  0.842243  0.744240         0.349333
# 12  0.708182     0.000000   0.716484  0.983903  0.829165         0.358242
# 16  0.639205     0.025641   0.660714  0.944681  0.777583         0.424107
# 20  0.625414     0.032573   0.651817  0.929766  0.766368         0.422062
# 24  0.634477     0.146893   0.683106  0.863395  0.762742         0.509295
# 1   0.834081     0.028571   0.844749  0.984043  0.909091         0.547374
# 5   0.618705     0.195219   0.698057  0.801029  0.746006         0.497513
# 9   0.604205     0.171254   0.690639  0.788787  0.736458         0.473760
# 13  0.596669     0.126615   0.696316  0.779678  0.735643         0.439576
# 17  0.607955     0.183761   0.668403  0.819149  0.736138         0.502170
# 21  0.647514     0.263844   0.690834  0.844482  0.759970         0.578176
# 25  0.557762     0.172316   0.655294  0.738727  0.694514         0.445864
# 3   0.843049     0.314286   0.880597  0.941489  0.910026         0.690299
# 7   0.864508     0.729084   0.887789  0.922813  0.904962         0.845210
# 11  0.885740     0.785933   0.910486  0.928292  0.919303         0.867102
# 15  0.908038     0.806202   0.926254  0.947686  0.936847         0.891698
# 19  0.849432     0.735043   0.872951  0.906383  0.889353         0.834624
# 23  0.861878     0.771987   0.885808  0.908027  0.896780         0.848726
# 27  0.886282     0.776836   0.899491  0.937666  0.918182         0.876764
#
#     macro_recall  macro_f1     kappa       mcc  hinge_loss    neg_f1   neg_roc
# 2       0.540198  0.536383  0.125698  0.220339    0.375151  0.153846  0.340198
# 6       0.469463  0.467902 -0.062929 -0.063113    0.751647  0.239496  0.551581
# 10      0.556435  0.551639  0.132107  0.145848    0.660458  0.303279  0.443848
# 14      0.460830  0.451059 -0.086534 -0.089092    0.697747  0.162080  0.536163
# 18      0.499354  0.487576 -0.001438 -0.001528    0.766216  0.246649  0.514098
# 22      0.523123  0.494059  0.055060  0.068367    0.745805  0.218447  0.462083
# 26      0.438168  0.427712 -0.133465 -0.136802    0.768264  0.170492  0.493933
# 0       0.500000  0.457421  0.000000  0.000000    0.404221  0.000000  0.444909
# 4       0.473967  0.404046 -0.068758 -0.115984    0.721560  0.013889  0.466340
# 8       0.427237  0.380969 -0.176863 -0.209408    0.776331  0.017699  0.697375
# 12      0.491952  0.414582 -0.022758 -0.067555    0.702170  0.000000  0.600600
# 16      0.485161  0.411348 -0.037890 -0.067117    0.783266  0.045113  0.530619
# 20      0.481170  0.411039 -0.047200 -0.076618    0.793899  0.055710  0.563521
# 24      0.505144  0.483532  0.012091  0.013829    0.782784  0.204322  0.519778
# 1       0.506307  0.480186  0.019722  0.034571    0.387846  0.051282  0.347340
# 5       0.498124  0.490792 -0.004157 -0.004320    0.722610  0.235577  0.511310
# 9       0.480021  0.470981 -0.044183 -0.045793    0.715011  0.205505  0.487546
# 13      0.453147  0.442631 -0.103416 -0.106416    0.704993  0.149618  0.565312
# 17      0.501455  0.486853  0.003283  0.003554    0.743090  0.237569  0.524314
# 21      0.554163  0.548384  0.121089  0.130142    0.747256  0.336798  0.493257
# 25      0.455522  0.446930 -0.095852 -0.098140    0.756034  0.199346  0.486724
# 3       0.627888  0.647995  0.301316  0.312005    0.308659  0.385965  0.165426
# 7       0.825948  0.834527  0.669361  0.670882    0.488436  0.764092  0.089156
# 11      0.857112  0.861842  0.723747  0.724145    0.459928  0.804382  0.060923
# 15      0.876944  0.883870  0.767821  0.768500    0.396376  0.830892  0.044210
# 19      0.820713  0.826899  0.654057  0.655189    0.542024  0.764444  0.086557
# 23      0.840007  0.844049  0.688195  0.688677    0.529981  0.791319  0.078840
# 27      0.857251  0.865896  0.732055  0.733756    0.472223  0.813609  0.055857
